# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import networkx as nx
from datetime import datetime, timedelta
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### Shark Data

# %%
df_sharks = pd.read_csv(r'/content/drive/Othercomputers/My Laptop/Node clustering//Data/Sharks.csv')
df_sharks.head(2)
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#   Shark  Transmitter Specie Sex  Length_cm Release date Killed date_killed  \
# 0  B01F         8806   Bull   F        255   27/11/2018     No         NaN
# 1  B07F         8807   Bull   F        275   10/12/2019     No         NaN
#
#    Latitude_RP  Longitude_RP  Latitude  Longitude
# 0    -22.60358     166.49282  -22.2758   166.3939
# 1    -22.74110     166.67033  -22.2874   166.3806

# %%
shark_attributes = df_sharks[['Shark', 'Specie', 'Sex',	'Length_cm'
                              ,	'Killed']].set_index('Shark').to_dict('index')

# %%
Sharks = df_sharks['Shark'].unique()
print(Sharks)
print(len(Sharks))
# Out:
# ['B01F' 'B07F' 'B02F' 'B04F' 'B09M' 'B03F' 'B05F' 'B06F' 'B08F' 'T01F'
#  'B17M' 'B11F' 'B10M' 'T02F' 'B12F' 'B13F' 'B14M' 'B15F' 'B16F' 'T03M'
#  'B18M' 'T05F' 'T07F' 'T10F' 'T04F' 'B19F' 'T06F' 'T08F' 'T11F' 'T09F']
# 30

# %% [markdown]
# ### Station Data

# %%
df_stations = pd.read_csv(r'/content/drive/Othercomputers/My Laptop/Node clustering//Data/Stations.csv')
df_stations.head(2)
# Out:
#   Receiver Station          Area  Depth_m   Latitude   Longitude StudyStarts  \
# 0      N05      H1  Grand Harbor      7.0 -22.266747  166.423083  28/11/2018
# 1      N01      H2  Grand Harbor     20.5 -22.237617  166.397767  04/12/2018
#
#   LastDataDownload       GrandZone1       GrandZone2        Place
# 0       20/10/2023             Quai             Quai  QuaiPecheur
# 1       23/08/2022  EntreeGrandRade  EntreeGrandRade    GrandRade

# %%
Stations = df_stations['Station'].unique()
Stations = Stations
print(Stations)
print(len(Stations))
# Out:
# ['H1' 'H2' 'H3' 'H4' 'C1' 'C2' 'C3' 'P1' 'V1' 'V2' 'V3' 'IC1' 'SM1' 'SM2'
#  'SM3' 'SM4' 'SM5' 'M1' 'IM1' 'M2' 'D1' 'IS1' 'IS3' 'IS2' 'C4' 'C5' 'C6'
#  'C7' 'V4' 'V5' 'V6' 'V7' 'V8' 'V9' 'V10' 'SM6' 'SM7' 'IC2' 'IC3' 'P2'
#  'P3' 'P4' 'P5' 'P6']
# 44

# %% [markdown]
# ### Detection Data

# %%
df_detections = pd.read_csv(r'/content/drive/Othercomputers/My Laptop/Node clustering//Data/Detections.csv')
df_detections['Localtime'] = pd.to_datetime(df_detections['Localtime'], format="%Y-%m-%d %H:%M:%S")
df_detections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363210 entries, 0 to 1363209
# Data columns (total 5 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Transmitter  1363210 non-null  int64
#  1   Receiver     1363210 non-null  object
#  2   Localtime    1363210 non-null  datetime64[ns]
#  3   Shark        1363210 non-null  object
#  4   Station      1363210 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 52.0+ MB

# %%
stations = df_detections['Station'].unique()

for station in stations:
    df = df_detections[df_detections['Station'] == station].sort_values(by='Localtime').reset_index(drop=True)

    blocks = []
    current_shark = None
    block_start = None
    block_end = None

    for i in range(len(df)):
        row = df.iloc[i]
        shark = row['Shark']
        time = row['Localtime']

        if current_shark is None:
            current_shark = shark
            block_start = time
            block_end = time
            continue

        if shark == current_shark:
            block_end = time
        else:
            # Save the previous block
            blocks.append({
                'Shark': current_shark,
                'First Seen': block_start if len(blocks) > 0 else pd.NaT,
                'Last Seen Before Next Shark': block_end,
                'Station': station
            })
            # Start new block
            current_shark = shark
            block_start = time
            block_end = time

    # Save the last block
    blocks.append({
        'Shark': current_shark,
        'First Seen': block_start,
        'Last Seen Before Next Shark': block_end,
        'Station': station
    })

    # Create dynamic block dataframe
    globals()[f"{station}_df_blocks"] = pd.DataFrame(blocks)

# %%
Areas = df_stations['Area'].unique()
print(Areas)
print(len(Areas))
# Out:
# ['Grand Harbor' 'Citrons Bay Wide Beach' 'Small Harbor'
#  'Vata Bay Wide Beach' 'Islets' 'Saint Marie Bay'
#  'Saint Marie Bay Nautical Center' 'Magenta Bay' 'Dumbea Bay'
#  'Citrons Bay Beachfront' 'Vata Bay Beachfront']
# 11

# %% [markdown]
# # Graph Construction

# %%
from time import time

# Use an undirected graph
G = nx.Graph()

# Add shark nodes with attributes
for shark, attributes in shark_attributes.items():
    G.add_node(shark, **attributes)

# Process each station
for station in Stations:
    print("-----------------------------------------------")
    print(f"Processing Station: {station}")
    beginning = time()

    df = globals()[f"{station}_df_blocks"]
    station_area = df_stations[df_stations['Station'] == station]['Area'].values[0]

    end = 1
    for start in range(len(df) - 1):
        shark1 = df.iloc[start]['Shark']
        shark1_last_seen = df.iloc[start]['Last Seen Before Next Shark']

        shark2 = df.iloc[end]['Shark']
        shark2_first_seen = df.iloc[end]['First Seen']

        time_diff = (shark2_first_seen - shark1_last_seen).total_seconds() / 60

        if time_diff <= 60:  # 60 minutes threshold
            # Build area presence dictionary
            area_attributes = {}
            for area_name in Areas:
                safe_key = area_name.replace(" ", "_")
                area_attributes[safe_key] = int(station_area == area_name)

            # Use sorted tuple to ensure consistent key for undirected edge
            u, v = sorted([shark1, shark2])

            if G.has_edge(u, v):
                G[u][v]['weight'] += 1
                G[u][v]['min_duration_m'] = round(min(G[u][v]['min_duration_m'], time_diff), 2)
                G[u][v]['max_duration_m'] = round(max(G[u][v]['max_duration_m'], time_diff), 2)

                # Update area presence
                for area_name in Areas:
                    safe_key = area_name.replace(" ", "_")
                    G[u][v][safe_key] = max(G[u][v].get(safe_key, 0), area_attributes[safe_key])
            else:
                G.add_edge(
                    u, v,
                    weight=1,
                    min_duration_m=round(time_diff, 2),
                    max_duration_m=round(time_diff, 2),
                    **area_attributes
                )

        end += 1

    ending = time()
    print(station, df.shape[0], round((ending - beginning) / 60, 2), 'min')
# Out:
# -----------------------------------------------
# Processing Station: H1
# H1 168094 1.04 min
# -----------------------------------------------
# Processing Station: H2
# H2 312 0.0 min
# -----------------------------------------------
# Processing Station: H3
# H3 3554 0.02 min
# -----------------------------------------------
# Processing Station: H4
# H4 1582 0.01 min
# -----------------------------------------------
# Processing Station: C1
# C1 494 0.0 min
# -----------------------------------------------
# Processing Station: C2
# C2 810 0.01 min
# -----------------------------------------------
# Processing Station: C3
# C3 420 0.0 min
# -----------------------------------------------
# Processing Station: P1
# P1 2347 0.02 min
# -----------------------------------------------
# Processing Station: V1
# V1 551 0.0 min
# -----------------------------------------------
# Processing Station: V2
# V2 220 0.0 min
# -----------------------------------------------
# Processing Station: V3
# V3 233 0.0 min
# -----------------------------------------------
# Processing Station: IC1
# IC1 646 0.0 min
# -----------------------------------------------
# Processing Station: SM1
# SM1 1220 0.01 min
# -----------------------------------------------
# Processing Station: SM2
# SM2 6011 0.03 min
# -----------------------------------------------
# Processing Station: SM3
# SM3 5039 0.03 min
# -----------------------------------------------
# Processing Station: SM4
# SM4 354 0.0 min
# -----------------------------------------------
# Processing Station: SM5
# SM5 422 0.0 min
# -----------------------------------------------
# Processing Station: M1
# M1 326 0.0 min
# -----------------------------------------------
# Processing Station: IM1
# IM1 300 0.0 min
# -----------------------------------------------
# Processing Station: M2
# M2 39 0.0 min
# -----------------------------------------------
# Processing Station: D1
# D1 634 0.0 min
# -----------------------------------------------
# Processing Station: IS1
# IS1 499 0.0 min
# -----------------------------------------------
# Processing Station: IS3
# IS3 208 0.0 min
# -----------------------------------------------
# Processing Station: IS2
# IS2 287 0.0 min
# -----------------------------------------------
# Processing Station: C4
# C4 380 0.0 min
# -----------------------------------------------
# Processing Station: C5
# C5 132 0.0 min
# -----------------------------------------------
# Processing Station: C6
# C6 132 0.0 min
# -----------------------------------------------
# Processing Station: C7
# C7 286 0.0 min
# -----------------------------------------------
# Processing Station: V4
# V4 87 0.0 min
# -----------------------------------------------
# Processing Station: V5
# V5 95 0.0 min
# -----------------------------------------------
# Processing Station: V6
# V6 90 0.0 min
# -----------------------------------------------
# Processing Station: V7
# V7 53 0.0 min
# -----------------------------------------------
# Processing Station: V8
# V8 60 0.0 min
# -----------------------------------------------
# Processing Station: V9
# V9 59 0.0 min
# -----------------------------------------------
# Processing Station: V10
# V10 139 0.0 min
# -----------------------------------------------
# Processing Station: SM6
# SM6 184 0.0 min
# -----------------------------------------------
# Processing Station: SM7
# SM7 576 0.0 min
# -----------------------------------------------
# Processing Station: IC2
# IC2 271 0.0 min
# -----------------------------------------------
# Processing Station: IC3
# IC3 658 0.0 min
# -----------------------------------------------
# Processing Station: P2
# P2 74 0.0 min
# -----------------------------------------------
# Processing Station: P3
# P3 235 0.0 min
# -----------------------------------------------
# Processing Station: P4
# P4 106 0.0 min
# -----------------------------------------------
# Processing Station: P5
# P5 28 0.0 min
# -----------------------------------------------
# Processing Station: P6
# P6 35 0.0 min

# %%
print("Number of Edges:", len(G.edges(data=True)))
# Out:
# Number of Edges: 164

# %%
# Output the graph structure
print("Nodes:", G.nodes)
print("Edges:", G.edges(data=True))
# Out:
# Nodes: ['B01F', 'B07F', 'B02F', 'B04F', 'B09M', 'B03F', 'B05F', 'B06F', 'B08F', 'T01F', 'B17M', 'B11F', 'B10M', 'T02F', 'B12F', 'B13F', 'B14M', 'B15F', 'B16F', 'T03M', 'B18M', 'T05F', 'T07F', 'T10F', 'T04F', 'B19F', 'T06F', 'T08F', 'T11F', 'T09F']
# Edges: [('B01F', 'B02F', {'weight': 2522, 'min_duration_m': 0.0, 'max_duration_m': 44.0, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B01F', 'B03F', {'weight': 1604, 'min_duration_m': 0.0, 'max_duration_m': 50.7, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 1, 'Small_Harbor': 1, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B01F', 'B04F', {'weight': 1048, 'min_duration_m': 0.0, 'max_duration_m': 55.47, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 1, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B02F', {'weight': 56, 'min_duration_m': 0.0, 'max_duration_m': 58.0, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 1, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B08F', {'weight': 16, 'min_duration_m': 0.0, 'max_duration_m': 0.43, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B04F', {'weight': 109, 'min_duration_m': 0.0, 'max_duration_m': 54.78, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B16F', {'weight': 30, 'min_duration_m': 0.0, 'max_duration_m': 4.38, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B15F', {'weight': 38, 'min_duration_m': 0.0, 'max_duration_m': 2.82, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B09M', {'weight': 22, 'min_duration_m': 0.0, 'max_duration_m': 1.1, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B14M', {'weight': 8, 'min_duration_m': 0.0, 'max_duration_m': 1.38, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B06F', {'weight': 4, 'min_duration_m': 9.73, 'max_duration_m': 31.58, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 1, 'Islets': 1, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay': 0, 'Citrons_Bay_Beachfront': 0, 'Vata_Bay_Beachfront': 0}), ('B07F', 'B05F', {'weight': 3, 'min_duration_m': 5.42, 'max_duration_m': 22.2, 'Grand_Harbor': 1, 'Citrons_Bay_Wide_Beach': 0, 'Small_Harbor': 0, 'Vata_Bay_Wide_Beach': 0, 'Islets': 0, 'Saint_Marie_Bay': 0, 'Saint_Marie_Bay_Nautical_Center': 0, 'Magenta_Bay': 0, 'Dumbea_Bay':  ...

# %%
graph_path = f"/content/drive/Othercomputers/My Laptop/Node clustering/Association rules/Graph.gml"
nx.write_gml(G, graph_path)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import pandas as pd
import numpy as np

# Extract edge data
edges_data = list(G.edges(data=True))

# Define area features and clean labels
area_features = [
    'Dumbea_Bay', 'Grand_Harbor', 'Small_Harbor', 'Citrons_Bay_Wide_Beach',
    'Citrons_Bay_Beachfront', 'Vata_Bay_Wide_Beach', 'Vata_Bay_Beachfront',
    'Islets', 'Saint_Marie_Bay', 'Saint_Marie_Bay_Nautical_Center', 'Magenta_Bay'
]
area_labels = [feature.replace('_', ' ') for feature in area_features]

# Extract edges and create edge labels
edge_pairs = []
feature_matrix = []

for edge in edges_data:
    node1, node2, attrs = edge
    edge_label = f"{node1}-{node2}"
    edge_pairs.append(edge_label)
    feature_values = [attrs.get(feature, 0) for feature in area_features]
    feature_matrix.append(feature_values)

feature_matrix = np.array(feature_matrix)

# Build DataFrame for plotting
plot_data = []
for i, edge_label in enumerate(edge_pairs):
    for j, feature_value in enumerate(feature_matrix[i]):
        if feature_value == 1:
            plot_data.append({
                'Edge': edge_label,
                'Area Feature': area_labels[j],
                'Presence': 'Yes'
            })

df_plot = pd.DataFrame(plot_data)

# Split into top and bottom edge sets
unique_edges = df_plot['Edge'].unique()
midpoint = len(unique_edges) // 2
edges_top = unique_edges[:midpoint]
edges_bottom = unique_edges[midpoint:]

df_top = df_plot[df_plot['Edge'].isin(edges_top)]
df_bottom = df_plot[df_plot['Edge'].isin(edges_bottom)]

# Create vertically stacked subplots
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Edges (Top Half)", "Edges (Bottom Half)"),
    shared_yaxes=True,
    vertical_spacing=0.1
)

# Add top subplot
fig.add_trace(
    go.Scatter(
        x=df_top['Edge'],
        y=df_top['Area Feature'],
        mode='markers',
        marker=dict(size=12, color='green', symbol='square'),
        name='Top'
    ),
    row=1, col=1
)

# Add bottom subplot
fig.add_trace(
    go.Scatter(
        x=df_bottom['Edge'],
        y=df_bottom['Area Feature'],
        mode='markers',
        marker=dict(size=12, color='green', symbol='square'),
        name='Bottom'
    ),
    row=2, col=1
)

# Set axis layout
fig.update_yaxes(
    title_text="Area Features",
    categoryorder='array',
    categoryarray=area_labels,
    showgrid=True,
    gridcolor='lightgray',
    zeroline=False,
    linecolor='gray',
    linewidth=1
)

fig.update_xaxes(
    tickangle=45,
    showgrid=True,
    gridcolor='lightgray',
    zeroline=False,
    linecolor='gray',
    linewidth=1
)

# Layout adjustments
fig.update_layout(
    height=1000,
    width=2000,
    title_text="",
    showlegend=False,
    plot_bgcolor='white',
    paper_bgcolor='white',
    margin=dict(t=50, b=50)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d93c1209-8897-4afa-b423-138040472c48" class="plotly-graph-div" style="height:1000px; width:2000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d93c1209-8897-4afa-b423-138040472c48")) {                    Plotly.newPlot(                        "d93c1209-8897-4afa-b423-138040472c48",                        [{"marker":{"color":"green","size":12,"symbol":"square"},"mode":"markers","name":"Top","x":["B01F-B02F","B01F-B03F","B01F-B03F","B01F-B03F","B01F-B04F","B01F-B04F","B07F-B02F","B07F-B02F","B07F-B08F","B07F-B04F","B07F-B16F","B07F-B15F","B07F-B09M","B07F-B14M","B07F-B06F","B07F-B06F","B07F-B06F","B07F-B05F","B02F-B03F","B02F-B03F","B02F-B03F","B02F-B06F","B02F-B05F","B02F-B04F","B02F-B04F","B02F-B04F","B02F-B08F","B02F-B15F","B02F-B16F","B02F-B16F","B02F-B16F","B02F-B09M","B02F-B14M","B02F-B14M","B02F-B14M","B02F-B11F","B02F-B13F","B02F-B12F","B02F-B18M","B02F-B18M","B02F-B19F","B02F-B19F","B02F-T06F","B02F-T06F","B02F-T09F","B02F-B10M","B04F-B03F","B04F-B03F","B04F-B03F","B04F-B03F","B04F-B03F","B04F-B03F","B04F-B06F","B04F-B06F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B08F","B04F-B09M","B04F-B09M","B04F-B09M","B04F-B05F","B04F-B05F","B04F-B05F","B04F-B15F","B04F-B16F","B04F-B12F","B04F-B12F","B04F-B11F","B04F-B11F","B04F-B11F","B04F-B11F","B04F-B14M","B04F-B14M","B04F-B14M","B04F-B14M","B04F-B14M","B04F-B14M","B04F-B14M","B04F-B13F","B04F-B18M","B04F-B18M","B04F-B18M","B04F-B18M","B04F-B18M","B04F-B18M","B04F-B18M","B04F-B19F","B04F-B19F","B04F-B19F","B04F-B17M","B04F-B17M","B04F-B17M","B04F-B17M","B04F-B17M","B04F-B17M","B04F-B17M","B04F-T06F","B04F-T06F","B04F-T06F","B04F-T06F","B04F-T06F","B04F-T06F","B04F-T09F","B04F-T05F","B04F-T05F","B04F-T05F","B04F-T05F","B04F-B10M","B04F-B10M","B04F-B10M","B04F-B10M","B04F-B10M","B04F-B10M","B04F-B10M","B04F-T03M","B04F-T03M","B04F-T03M","B04F-T03M","B04F-T10F","B04F-T10F","B04F-T04F","B04F-T04F","B04F-T02F","B04F-T02F","B04F-T01F","B04F-T08F","B09M-B06F","B09M-B05F","B09M-B05F","B09M-B05F","B09M-B05F","B09M-B05F","B09M-B05F","B09M-B05F","B09M-B12F","B09M-B16F","B09M-B11F","B09M-B14M","B09M-B14M","B09M-B14M","B09M-B13F","B09M-B15F","B09M-B17M","B09M-T01F","B03F-B06F","B03F-B06F","B03F-B05F","B05F-B06F","B05F-B06F","B05F-B12F","B05F-B13F","B05F-B14M","B05F-B14M","B05F-B16F","B05F-B15F","B05F-B11F","B05F-B11F","B05F-B18M","B05F-T02F","B06F-B08F","B06F-B12F","B06F-B13F","B06F-B14M","B06F-B14M","B06F-B16F","B06F-B15F","B06F-B11F","B06F-B11F","B06F-B19F"],"y":["Grand Harbor","Grand Harbor","Small Harbor","Citrons Bay Wide Beach","Grand Harbor","Small Harbor","Grand Harbor","Vata Bay Wide Beach","Grand Harbor","Grand Harbor","Grand Harbor","Grand Harbor","Grand Harbor","Grand Harbor","Grand Harbor","Vata Bay Wide Beach","Islets","Grand Harbor","Grand Harbor","Vata Bay Wide Beach","Islets","Grand Harbor","Grand Harbor","Grand Harbor","Small Harbor","Citrons Bay Wide Beach","Grand Harbor","Grand Harbor","Dumbea Bay","Grand Harbor","Islets","Grand Harbor","Grand Harbor","Small Harbor","Citrons Bay Wide Beach","Grand Harbor","Grand Harbor","Grand Harbor","Grand Harbor","Small Harbor","Dumbea Bay","Grand Harbor","Dumbea Bay","Grand Harbor","Grand Harbor","Saint Marie Bay","Grand Harbor","Small Harbor","Citrons Bay Wide Beach","Vata Bay Wide Beach","Islets","Saint Marie Bay","Grand Harbor","Small Harbor","Grand Harbor","Small Harbor","Citrons Bay Wide Beach","Citrons Bay Beachfront","Vata Bay Wide Beach","Vata Bay Beachfront","Islets","Saint Marie Bay","Grand Harbor","Small Harbor","Islets","Grand Harbor","Small Harbor","Islets","Grand Harbor","Grand Harbor","Grand Harbor","Small Harbor","Grand Harbor","Small Harbor","Vata Bay Wide Beach","Islets","Grand Harbor","Small Harbor","Citrons Bay W ...
